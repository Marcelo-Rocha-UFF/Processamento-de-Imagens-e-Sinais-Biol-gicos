# %% [markdown]
# <a href="https://colab.research.google.com/github/Marcelo-Rocha-UFF/Processamento-de-Imagens-e-Sinais-Biologicos/blob/main/reconhecimento-facial-estudo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Acessando o GDRIVE**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import cv2
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# !pip install face_recognition;
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.1/100.1 MB 5.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566170 sha256=4cb4817b241ea5dd1ce3f3f8891ccd9a7346475552df1293c3cb92b9c9e7c7e2
#   Stored in directory: /root/.cache/pip/wheels/7a/eb/cf/e9eced74122b679557f597bb7c8e4c739cfcac526db1fd523d
# Successfully built face-recognition-models
# ...

# %%
import face_recognition as fr

# %%
luiza_vector = np.load("/content/drive/MyDrive/users_face_recog/luiza_9-3-2024-10-55-21.npy")
luiza_foto = cv2.imread("/content/drive/MyDrive/users_face_recog/luiza_9-3-2024-10-55-21.jpg",1)

suzana_vector = np.load("/content/drive/MyDrive/users_face_recog/susana_9-3-2024-10-52-8.npy")
suzana_foto = cv2.imread("/content/drive/MyDrive/users_face_recog/susana_9-3-2024-10-52-8.jpg",1)

pedrolucas_vector = np.load("/content/drive/MyDrive/users_face_recog/pedrolucas_29-5-2024-11-1-37.npy")
pedrolucas_foto = cv2.imread("/content/drive/MyDrive/users_face_recog/pedrolucas_29-5-2024-11-1-37.jpg",1)

pedrovalentim_vector = np.load("/content/drive/MyDrive/users_face_recog/pedrovalentim_29-5-2024-9-32-36.npy")
pedrovalentim_foto = cv2.imread("/content/drive/MyDrive/users_face_recog/pedrovalentim_29-5-2024-9-32-36.jpg",1)

yasmim_vector = np.load("/content/drive/MyDrive/users_face_recog/yasmim_29-5-2024-15-5-16.npy")
yasmim_foto = cv2.imread("/content/drive/MyDrive/users_face_recog/yasmim_29-5-2024-15-5-16.jpg",1)

luiza2_foto = cv2.imread("/content/drive/MyDrive/users_face_recog/luiza2.jpg",1)
suzana2_foto = cv2.imread("/content/drive/MyDrive/users_face_recog/suzana2.jpg",1)

luiza3_foto = cv2.imread("/content/drive/MyDrive/users_face_recog/luiza3.jpg",1)
suzana3_foto = cv2.imread("/content/drive/MyDrive/users_face_recog/suzana3.jpg",1)

# %% [markdown]
# #**Ploting Images and Encoding Users Photos**

# %% [markdown]
# ##**User: Luiza**

# %%
plt.imshow(cv2.cvtColor(luiza_foto, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()

# %% [markdown]
# ##**User: Luiza2**

# %%
plt.imshow(cv2.cvtColor(luiza2_foto, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()

# %% [markdown]
# ##**Luiza 2 - Photo Encoding (Generating the Feature Vector)**

# %%
luiza2_vector = fr.face_encodings(luiza2_foto)[0] # A numpy array

# %% [markdown]
# ##**User: Luiza3**

# %%
plt.imshow(cv2.cvtColor(luiza3_foto, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()

# %% [markdown]
# ##**Luiza 3 - Photo Encoding (Generating the Feature Vector)**

# %%
luiza3_vector = fr.face_encodings(luiza3_foto)[0] # A numpy array

# %% [markdown]
# ##**User: Suzana**

# %%
plt.imshow(cv2.cvtColor(suzana_foto, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()

# %% [markdown]
# # **User: Suzana2**

# %%
plt.imshow(cv2.cvtColor(suzana2_foto, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()

# %% [markdown]
# #**Suzana 2 - Photo Encoding (Generating the Feature Vector)**

# %%
suzana2_vector = fr.face_encodings(suzana2_foto)[0] # A numpy array

# %% [markdown]
# #**User: Suzana3**

# %%
plt.imshow(cv2.cvtColor(suzana3_foto, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()

# %% [markdown]
# #**Suzana 3 - Photo Encoding (Generating the Feature Vector)**

# %%
suzana3_vector = fr.face_encodings(suzana3_foto)[0] # A numpy array

# %%
x = range(0, 128)
plt.figure(figsize=(15, 6))
plt.title("Comparando os Vetores de Dois Usuários")
plt.xlabel("Dimension (Feature)")
plt.ylabel("Value")
plt.plot(x, luiza_vector, color="blue", marker="+", label="Luiza")
plt.plot(x, suzana_vector, color="red", marker=".", label="Suzana")

#plt.plot(x, luiza_vector, color="blue", marker="+", label="Luiza")
#plt.plot(x, luiza2_vector, color="red", marker="+", label="Luiza2")

# plt.plot(x, luiza2_vector, color="blue", marker="+", label="Luiza2")
# plt.plot(x, luiza3_vector, color="red", marker="+", label="Luiza3")

# plt.plot(x, suzana_vector, color="blue", marker="+", label="Suzana")
# plt.plot(x, suzana2_vector, color="red", marker="+", label="Suzana2")

# plt.plot(x, suzana_vector, color="blue", marker="+", label="Suzana2")
# plt.plot(x, suzana2_vector, color="red", marker="+", label="Suzana3")

plt.legend()
plt.show()

# %% [markdown]
# #**User: Pedro Lucas**

# %%
plt.imshow(cv2.cvtColor(pedrolucas_foto, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()

# %% [markdown]
# #**User: Pedro Valentim**

# %%
plt.imshow(cv2.cvtColor(pedrovalentim_foto, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()

# %% [markdown]
# #**User: Yasmim**

# %%
plt.imshow(cv2.cvtColor(yasmim_foto, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()

# %%
x = range(0, 128)
plt.figure(figsize=(15, 6))
plt.title("Comparing Two Users Vectors")
plt.xlabel("Dimension (Feature)")
plt.ylabel("Value")
plt.plot(x, luiza_vector, color="blue", marker=".", label="Luiza")
plt.plot(x, yasmim_vector, color="green", marker="+", label="Yasmim")
#plt.plot(x, pedrovalentim_vector, color="red", marker="*", label="Pedro Valentim")

plt.legend()
plt.show()

# %% [markdown]
# #**Let's to measure the vector distances between two users**

# %% [markdown]
# ###**Measuring the distances between Luiza and Yasmim vectors.**

# %%
distance = fr.face_distance([luiza_vector], yasmim_vector)
print(distance)
# Out:
# [0.74762952]

# %% [markdown]
# ###**Measuring the distances between Pedro Lucas and Yasmim vectors.**

# %%
distance = fr.face_distance([pedrolucas_vector], yasmim_vector)
print(distance)
# Out:
# [0.79875241]

# %% [markdown]
# ###**Measuring the distances between Luiza and Suzana vectors.**

# %%
distance = fr.face_distance([luiza_vector], suzana_vector)
print(distance)
# Out:
# [0.56620867]

# %% [markdown]
# ###**Measuring the distances between Luiza and Pedro Valentim vectors.**

# %%
distance = fr.face_distance([luiza_vector], pedrovalentim_vector)
print(distance)
# Out:
# [0.72667302]

# %% [markdown]
# ###**Measuring the distances between Luiza and Pedro Lucas vectors.**

# %%
distance = fr.face_distance([luiza_vector], pedrolucas_vector)
print(distance)
# Out:
# [0.65802504]

# %% [markdown]
# ###**Measuring the distances between Pedro Valentim and Pedro Lucas vectors.**

# %%
distance = fr.face_distance([pedrovalentim_vector], pedrolucas_vector)
print(distance)
# Out:
# [0.62782337]

# %% [markdown]
# ###**Measuring the distances between Luiza and Luiza2 vectors.**

# %%
distance = fr.face_distance([luiza_vector], luiza2_vector)
print(distance)
# Out:
# [0.44160735]

# %% [markdown]
# ###**Measuring the distances between Suzana and Suzana2 vectors.**

# %%
distance = fr.face_distance([suzana_vector], suzana2_vector)
print(distance)
# Out:
# [0.53078708]

# %% [markdown]
# ###**Measuring the distances between Luiza2 and Luiza3 vectors.**

# %%
distance = fr.face_distance([luiza2_vector], luiza3_vector)
print(distance)
# Out:
# [0.38877178]

# %% [markdown]
# ###**Measuring the distances between Suzana2 and Suzana3 vectors.**

# %%
distance = fr.face_distance([suzana2_vector], suzana3_vector)
print(distance)
# Out:
# [0.48861427]
